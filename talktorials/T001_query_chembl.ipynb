# %% [markdown]
# ### T001_query_chembl

# %%
# !pip install chembl_webresource_client

import math
from pathlib import Path
from zipfile import ZipFile
from tempfile import TemporaryDirectory

import numpy as np
import pandas as pd
from rdkit.Chem import PandasTools
from chembl_webresource_client.new_client import new_client
from tqdm.auto import tqdm
# Out:
# Requirement already satisfied: chembl_webresource_client in /opt/conda/lib/python3.9/site-packages (0.10.8)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.9/site-packages (from chembl_webresource_client) (1.26.9)
# Requirement already satisfied: requests-cache~=0.7.0 in /opt/conda/lib/python3.9/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /opt/conda/lib/python3.9/site-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: requests>=2.18.4 in /opt/conda/lib/python3.9/site-packages (from chembl_webresource_client) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (2022.6.15)
# Requirement already satisfied: itsdangerous>=2.0.1 in /opt/conda/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /opt/conda/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: attrs<22.0,>=21.2 in /opt/conda/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /opt/conda/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data"

# %%
# Create resource objects for API access
targets_api = new_client.target
compounds_api = new_client.molecule
bioactivities_api = new_client.activity

# %% [markdown]
# ### Import target

# %%
# Get target information from ChEMBL but restrict it to specified values only
uniprot_id = "Q07820"
targets = targets_api.get(target_components__accession=uniprot_id).only(
    "target_chembl_id", "organism", "pref_name", "target_type"
)
targets = pd.DataFrame.from_records(targets)
targets
# Out:
#        organism                                          pref_name  \
# 0  Homo sapiens  Induced myeloid leukemia cell differentiation ...
# 1  Homo sapiens  Induced myeloid leukemia cell differentiation ...
# 2  Homo sapiens  Induced myeloid leukemia cell differentiation ...
# 3  Homo sapiens  Induced myeloid leukemia cell differentiation ...
# 4  Homo sapiens  Apoptosis regulator BAX/Induced myeloid leukem...
# 5  Homo sapiens                                  MCL1-BAK1 complex
# 6  Homo sapiens                              MCL1/Protein cereblon
#
#   target_chembl_id                  target_type
# 0       CHEMBL4361               SINGLE PROTEIN
# 1       CHEMBL4361               SINGLE PROTEIN
# 2    CHEMBL3430886  PROTEIN-PROTEIN INTERACTION
# 3    CHEMBL3430887  PROTEIN-PROTEIN INTERACTION
# 4    CHEMBL3885515  PROTEIN-PROTEIN INTERACTION
# 5    CHEMBL3885523              PROTEIN COMPLEX
# 6    CHEMBL4523712  PROTEIN-PROTEIN INTERACTION

# %%
# Select the first entry as our target of interest (target ChEMBL ID: CHEMBL4361)
# CHEMBL4361: It is a single protein and represents the Induced myeloid leukemia cell differentiation protein Mcl-1
target = targets.iloc[0]
chembl_id = target.target_chembl_id
print(f"The target ChEMBL ID is {chembl_id}")
# Out:
# The target ChEMBL ID is CHEMBL4361

# %% [markdown]
# ### Fetch bioactivity data for the target from ChEMBL

# %%
# Filter it to only consider：human proteins,bioactivity type IC50,exact measurements (relation '='), and binding data (assay type 'B').
bioactivities = bioactivities_api.filter(
    target_chembl_id=chembl_id, type="IC50", relation="=", assay_type="B"
).only(
    "activity_id",
    "assay_chembl_id",
    "assay_description",
    "assay_type",
    "molecule_chembl_id",
    "type",
    "standard_units",
    "relation",
    "standard_value",
    "target_chembl_id",
    "target_organism",
)

print(f"Length and type of bioactivities object: {len(bioactivities)}, {type(bioactivities)}")
print(f"Length and type of first element: {len(bioactivities[0])}, {type(bioactivities[0])}")
bioactivities[0]
# Out:
# Length and type of bioactivities object: 554, <class 'chembl_webresource_client.query_set.QuerySet'>
# Length and type of first element: 13, <class 'dict'>
# {'activity_id': 1773940,
#  'assay_chembl_id': 'CHEMBL909447',
#  'assay_description': 'Displacement of FAM-Bid from human Mcl1 by FP assay',
#  'assay_type': 'B',
#  'molecule_chembl_id': 'CHEMBL410802',
#  'relation': '=',
#  'standard_units': 'nM',
#  'standard_value': '52.0',
#  'target_chembl_id': 'CHEMBL4361',
#  'target_organism': 'Homo sapiens',
#  'type': 'IC50',
#  'units': 'uM',
#  'value': '0.052'}

# %%
# only download IC 50 value as bioactivity data from website
bioactivities_df = pd.read_csv(DATA/ "MCL_download.csv",sep=";")
print(f"DataFrame shape: {bioactivities_df.shape}")
bioactivities_df.head()
# Out:
# DataFrame shape: (1825, 45)
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0      CHEMBL3126318           NaN                   0            256.30
# 1      CHEMBL3126322           NaN                   0            300.35
# 2      CHEMBL3126311           NaN                   0            527.60
# 3      CHEMBL3126333           NaN                   0            303.34
# 4      CHEMBL3963557           NaN                   0            421.46
#
#   #RO5 Violations AlogP Compound Key  \
# 0               0  3.71           36
# 1               0  4.07           40
# 2               2  5.59           24
# 3               0  2.83            1
# 4               1  5.82   BDBM231571
#
#                                               Smiles Standard Type  \
# 0                  CCCc1ccc(-c2ccc(O)c(C(=O)O)c2)cc1          IC50
# 1             CC(C)(C)OCc1ccccc1-c1ccc(O)c(C(=O)O)c1          IC50
# 2  Cc1ccc(-c2ccc(C(=O)O)c(NS(=O)(=O)c3ccc(OCCn4cc...          IC50
# 3            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1          IC50
# 4  COc1cccc(-c2ccc3nc(-c4ccco4)cc(C(=O)Nc4cccnc4)...          IC50
#
#   Standard Relation  ...                                        Target Name  \
# 0               '='  ...  Induced myeloid leukemia cell differentiation ...
# 1               '>'  ...  Induced myeloid leukemia cell differentiation ...
# 2               '='  ...  Induced myeloid leukemia cell differentiation ...
# 3               '='  ...  Induced myeloid leukemia cell differentiation ...
# 4               '='  ...  Induced myeloid leukemia cell differentiation ...
#
#   Target Organism     Target Type Document ChEMBL ID Source ID  \
# 0    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 1    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 2    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 3    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 4    Homo sapiens  SINGLE PROTEIN      CHEMBL3886732        37
#
#       Source Description          Document Journal Document Year  \
# 0  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 1  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 2  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 3  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 4     BindingDB Database                       NaN        2016.0
#
#   Cell ChEMBL ID Properties
# 0           None        NaN
# 1           None        NaN
# 2           None        NaN
# 3           None        NaN
# 4           None        NaN
#
# [5 rows x 45 columns]

# %%
bioactivities_df.dtypes
# Out:
# Molecule ChEMBL ID             object
# Molecule Name                  object
# Molecule Max Phase              int64
# Molecular Weight              float64
# #RO5 Violations                object
# AlogP                          object
# Compound Key                   object
# Smiles                         object
# Standard Type                  object
# Standard Relation              object
# Standard Value                float64
# Standard Units                 object
# pChEMBL Value                 float64
# Data Validity Comment          object
# Comment                        object
# Uo Units                       object
# Ligand Efficiency BEI         float64
# Ligand Efficiency LE           object
# Ligand Efficiency LLE          object
# Ligand Efficiency SEI          object
# Potential Duplicate             int64
# Assay ChEMBL ID                object
# Assay Description              object
# Assay Type                     object
# BAO Format ID                  object
# BAO Label                      object
# Assay Organism                 object
# Assay Tissue ChEMBL ID         object
# Assay Tissue Name              object
# Assay Cell Type                object
# Assay Subcellular Fraction     object
# Assay Parameters               object
# Assay Variant Accession       float64
# Assay Variant Mutation        float64
# Target ChEMBL ID               object
# Target Name                    object
# Target Organism                object
# Target Type                    object
# Document ChEMBL ID             object
# Source ID                       int64
# Source Description             object
# Document Journal               object
# Document Year                 float64
# Cell ChEMBL ID                 object
# Properties                     object
# dtype: object

# %%
# Keep only entries with "standard_unit == nM“ and binding data (assay type 'B'）
print(f"Units in downloaded data: {bioactivities_df['Standard Units'].unique()}")
print(
    f"Number of non-nM entries:\
    {bioactivities_df[bioactivities_df['Standard Units'] != 'nM'].shape[0]}"
)

print(f"Binding data in downloaded data: {bioactivities_df['Assay Type'].unique()}")
print(
    f"Number of non-binding entries:\
    {bioactivities_df[bioactivities_df['Assay Type'] != 'B'].shape[0]}"
)
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# Units in downloaded data: ['nM' nan 'ug.mL-1' 'µM']
# Number of non-nM entries:    23
# Binding data in downloaded data: ['B' 'F']
# Number of non-binding entries:    1106
# DataFrame shape: (1825, 45)

# %%
bioactivities_df = bioactivities_df[bioactivities_df["Standard Units"] == "nM"]
bioactivities_df = bioactivities_df[bioactivities_df["Assay Type"] == "B"]
bioactivities_df = bioactivities_df[bioactivities_df["Standard Relation"] == "'='"]
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (553, 45)

# %%
#Reset "DataFrame" index
bioactivities_df.reset_index(drop=True, inplace=True)
bioactivities_df.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0      CHEMBL3126318           NaN                   0            256.30
# 1      CHEMBL3126311           NaN                   0            527.60
# 2      CHEMBL3126333           NaN                   0            303.34
# 3      CHEMBL3963557           NaN                   0            421.46
# 4      CHEMBL3951188           NaN                   0            504.60
#
#   #RO5 Violations AlogP Compound Key  \
# 0               0  3.71           36
# 1               2  5.59           24
# 2               0  2.83            1
# 3               1  5.82   BDBM231571
# 4               2  7.63   BDBM231610
#
#                                               Smiles Standard Type  \
# 0                  CCCc1ccc(-c2ccc(O)c(C(=O)O)c2)cc1          IC50
# 1  Cc1ccc(-c2ccc(C(=O)O)c(NS(=O)(=O)c3ccc(OCCn4cc...          IC50
# 2            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1          IC50
# 3  COc1cccc(-c2ccc3nc(-c4ccco4)cc(C(=O)Nc4cccnc4)...          IC50
# 4  O=C(Nc1nc2ccccc2s1)c1cc(-c2ccco2)nc2ccc(-c3ccc...          IC50
#
#   Standard Relation  ...                                        Target Name  \
# 0               '='  ...  Induced myeloid leukemia cell differentiation ...
# 1               '='  ...  Induced myeloid leukemia cell differentiation ...
# 2               '='  ...  Induced myeloid leukemia cell differentiation ...
# 3               '='  ...  Induced myeloid leukemia cell differentiation ...
# 4               '='  ...  Induced myeloid leukemia cell differentiation ...
#
#   Target Organism     Target Type Document ChEMBL ID Source ID  \
# 0    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 1    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 2    Homo sapiens  SINGLE PROTEIN      CHEMBL3124895         1
# 3    Homo sapiens  SINGLE PROTEIN      CHEMBL3886732        37
# 4    Homo sapiens  SINGLE PROTEIN      CHEMBL3886732        37
#
#       Source Description          Document Journal Document Year  \
# 0  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 1  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 2  Scientific Literature  Bioorg. Med. Chem. Lett.        2014.0
# 3     BindingDB Database                       NaN        2016.0
# 4     BindingDB Database                       NaN        2016.0
#
#   Cell ChEMBL ID Properties
# 0           None        NaN
# 1           None        NaN
# 2           None        NaN
# 3           None        NaN
# 4           None        NaN
#
# [5 rows x 45 columns]

# %%
bioactivities_df.rename(
    columns={"Molecule ChEMBL ID":"molecule_chembl_id","Standard Value": "IC50", "Standard Units": "units"}, inplace=True
)
bioactivities_df.dtypes
# Out:
# molecule_chembl_id             object
# Molecule Name                  object
# Molecule Max Phase              int64
# Molecular Weight              float64
# #RO5 Violations                object
# AlogP                          object
# Compound Key                   object
# Smiles                         object
# Standard Type                  object
# Standard Relation              object
# IC50                          float64
# units                          object
# pChEMBL Value                 float64
# Data Validity Comment          object
# Comment                        object
# Uo Units                       object
# Ligand Efficiency BEI         float64
# Ligand Efficiency LE           object
# Ligand Efficiency LLE          object
# Ligand Efficiency SEI          object
# Potential Duplicate             int64
# Assay ChEMBL ID                object
# Assay Description              object
# Assay Type                     object
# BAO Format ID                  object
# BAO Label                      object
# Assay Organism                 object
# Assay Tissue ChEMBL ID         object
# Assay Tissue Name              object
# Assay Cell Type                object
# Assay Subcellular Fraction     object
# Assay Parameters               object
# Assay Variant Accession       float64
# Assay Variant Mutation        float64
# Target ChEMBL ID               object
# Target Name                    object
# Target Organism                object
# Target Type                    object
# Document ChEMBL ID             object
# Source ID                       int64
# Source Description             object
# Document Journal               object
# Document Year                 float64
# Cell ChEMBL ID                 object
# Properties                     object
# dtype: object

# %%
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (553, 45)

# %%
#Fetch compound data from ChEMBL
compounds_provider = compounds_api.filter(
    molecule_chembl_id__in=list(bioactivities_df["molecule_chembl_id"])
).only("molecule_chembl_id", "molecule_structures")
compounds = list(tqdm(compounds_provider))
# Out:
#   0%|          | 0/518 [00:00<?, ?it/s]

# %%
compounds_df = pd.DataFrame.from_records(
    compounds,
)
print(f"DataFrame shape: {compounds_df.shape}")
compounds_df.head()
# Out:
# DataFrame shape: (518, 2)
#   molecule_chembl_id                                molecule_structures
# 0         CHEMBL6466  {'canonical_smiles': 'O=c1ccc2ccccc2o1', 'molf...
# 1       CHEMBL276618  {'canonical_smiles': 'Cc1cc(=O)oc2c(O)c(O)ccc1...
# 2        CHEMBL12208  {'canonical_smiles': 'Cc1cc(=O)oc2cc(O)ccc12',...
# 3        CHEMBL51483  {'canonical_smiles': 'Cc1cc2c(C(C)C)c(O)c(O)c(...
# 4        CHEMBL51628  {'canonical_smiles': 'O=c1ccc2ccc(O)cc2o1', 'm...

# %%
compounds_df = pd.DataFrame.from_records(
    compounds,
)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (518, 2)

# %% [markdown]
# ### Preprocess and filter compound data

# %%
#1. Remove entries with missing entries 
compounds_df.dropna(axis=0, how="any", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
#2. Delete duplicate molecules
compounds_df.drop_duplicates("molecule_chembl_id", keep="first", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
#3. Get molecules with canonical SMILES
compounds_df.iloc[0].molecule_structures.keys()

canonical_smiles = []

for i, compounds in compounds_df.iterrows():
    try:
        canonical_smiles.append(compounds["molecule_structures"]["canonical_smiles"])
    except KeyError:
        canonical_smiles.append(None)

compounds_df["smiles"] = canonical_smiles
compounds_df.drop("molecule_structures", axis=1, inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (518, 2)
# DataFrame shape: (518, 2)
# DataFrame shape: (518, 2)

# %%
# Output (bioactivity-compound) data
print(f"Bioactivities filtered: {bioactivities_df.shape[0]}")
bioactivities_df.columns
# Out:
# Bioactivities filtered: 553
# Index(['molecule_chembl_id', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'IC50', 'units',
#        'pChEMBL Value', 'Data Validity Comment', 'Comment', 'Uo Units',
#        'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
#       dtype='object')

# %%
# Output compounds data
print(f"Compounds filtered: {compounds_df.shape[0]}")
compounds_df.columns
# Out:
# Compounds filtered: 518
# Index(['molecule_chembl_id', 'smiles'], dtype='object')

# %%
# Merge DataFrames
output_df = pd.merge(
    bioactivities_df[["molecule_chembl_id", "IC50", "units"]],
    compounds_df,
    on='molecule_chembl_id',
)

# Reset row indices
output_df.reset_index(drop=True, inplace=True)

print(f"Dataset with {output_df.shape[0]} entries.")
# Out:
# Dataset with 553 entries.

# %%
output_df.dtypes
# Out:
# molecule_chembl_id     object
# IC50                  float64
# units                  object
# smiles                 object
# dtype: object

# %%
output_df.head(10)
# Out:
#   molecule_chembl_id    IC50 units  \
# 0      CHEMBL3126318  3300.0    nM
# 1      CHEMBL3126311    30.0    nM
# 2      CHEMBL3126333  5000.0    nM
# 3      CHEMBL3126333  5000.0    nM
# 4      CHEMBL3963557  1500.0    nM
# 5      CHEMBL3951188  4800.0    nM
# 6      CHEMBL3975916  5000.0    nM
# 7      CHEMBL3909705  6300.0    nM
# 8      CHEMBL3924786  2400.0    nM
# 9      CHEMBL3984546  8600.0    nM
#
#                                               smiles
# 0                  CCCc1ccc(-c2ccc(O)c(C(=O)O)c2)cc1
# 1  Cc1ccc(-c2ccc(C(=O)O)c(NS(=O)(=O)c3ccc(OCCn4cc...
# 2            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1
# 3            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1
# 4  COc1cccc(-c2ccc3nc(-c4ccco4)cc(C(=O)Nc4cccnc4)...
# 5  O=C(Nc1nc2ccccc2s1)c1cc(-c2ccco2)nc2ccc(-c3ccc...
# 6  O=C(Nc1cccnc1)c1cc(-c2ccco2)nc2ccc(-c3ccc(F)cc...
# 7  O=C(Nc1cccnc1)c1cc(-c2ccco2)nc2ccc(-c3cccc(Oc4...
# 8  O=C(Nc1cccnc1)c1cc(-c2ccco2)nc2ccc(-c3ccc4cc[n...
# 9  CN1CCN(C(=O)c2cc(-c3ccco3)nc3ccc(-c4ccc5scnc5c...

# %%
#Add pIC50 values
def convert_ic50_to_pic50(IC50_value):
    pIC50_value = 9 - math.log10(IC50_value)
    return pIC50_value

# Apply conversion to each row of the compounds DataFrame
output_df["pIC50"] = output_df.apply(lambda x: convert_ic50_to_pic50(x.IC50), axis=1)

output_df.head()
# Out:
#   molecule_chembl_id    IC50 units  \
# 0      CHEMBL3126318  3300.0    nM
# 1      CHEMBL3126311    30.0    nM
# 2      CHEMBL3126333  5000.0    nM
# 3      CHEMBL3126333  5000.0    nM
# 4      CHEMBL3963557  1500.0    nM
#
#                                               smiles     pIC50
# 0                  CCCc1ccc(-c2ccc(O)c(C(=O)O)c2)cc1  5.481486
# 1  Cc1ccc(-c2ccc(C(=O)O)c(NS(=O)(=O)c3ccc(OCCn4cc...  7.522879
# 2            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1  5.301030
# 3            C=Cc1ccc(C(=O)O)c(NS(=O)(=O)c2ccccc2)c1  5.301030
# 4  COc1cccc(-c2ccc3nc(-c4ccco4)cc(C(=O)Nc4cccnc4)...  5.823909

# %%
#Draw compound data
#1.plot the pIC50 value distribution
output_df.hist(column="pIC50")
# Out:
# array([[<AxesSubplot:title={'center':'pIC50'}>]], dtype=object)

# %%
# Add molecule column
PandasTools.AddMoleculeColumnToFrame(output_df, smilesCol="smiles")

# Sort molecules by pIC50
output_df.sort_values(by="pIC50", ascending=False, inplace=True)

# Reset index
output_df.reset_index(drop=True, inplace=True)

# %%
#how the three most active molecules, i.e. molecules with the highest pIC50 values.
output_df.drop("smiles", axis=1).head(3)
# Out:
#   molecule_chembl_id  IC50 units    pIC50  \
# 0      CHEMBL4535151   0.2    nM  9.69897
# 1      CHEMBL4580244   0.2    nM  9.69897
# 2      CHEMBL4553660   0.2    nM  9.69897
#
#                                                ROMol
# 0  <img data-content="rdkit/molecule" src="data:i...
# 1  <img data-content="rdkit/molecule" src="data:i...
# 2  <img data-content="rdkit/molecule" src="data:i...

# %%
#Write output data to file
output_df.to_csv(DATA / "MCL_compounds.csv")
output_df.head()
# Out:
#   molecule_chembl_id  IC50 units  \
# 0      CHEMBL4535151   0.2    nM
# 1      CHEMBL4580244   0.2    nM
# 2      CHEMBL4553660   0.2    nM
# 3      CHEMBL4464768   0.3    nM
# 4      CHEMBL4446369   0.3    nM
#
#                                               smiles     pIC50  \
# 0  CN(C)C(=O)CO[C@H]1/C=C/CCN(C)C(=O)C[C@](O)(C(=...  9.698970
# 1  CN1CC/C=C/[C@H](OCCN2CCS(=O)(=O)CC2)[C@@H]2CC[...  9.698970
# 2  CN1CC/C=C/[C@H](OCCN2CCOCC2)[C@@H]2CC[C@H]2CN2...  9.698970
# 3  CN1CC/C=C/[C@H](OCCNCC(F)(F)CO)[C@@H]2CC[C@H]2...  9.522879
# 4  CN1CC/C=C/[C@H](OCCN2CC(F)(F)C2)[C@@H]2CC[C@H]...  9.522879
#
#                                                ROMol
# 0  <img data-content="rdkit/molecule" src="data:i...
# 1  <img data-content="rdkit/molecule" src="data:i...
# 2  <img data-content="rdkit/molecule" src="data:i...
# 3  <img data-content="rdkit/molecule" src="data:i...
# 4  <img data-content="rdkit/molecule" src="data:i...

# %%
print(f"DataFrame shape: {output_df.shape}")
# Out:
# DataFrame shape: (553, 6)
